# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### Lane 1: Ranking Signal Analysis
#
# Question:
#
# ```text
# Which safe content and search signals are associated with visibility, clicks, engagement, or movement?
# ```
#
# Can train a model using the dataset provided to determine which features of a webpage are most likely to improve performance and engagement for that page. Using data from already existing webpages and see which ones are high performing and get the most engagement by training a model to analyse the data and find correlations between search signals and clicks and output most effective search signals.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Work improves the performance of webpages and different companies and organisations can use the results to optimise their websites to get the maximum amount of engagment from users as possible. A wrong action could mean that companies end up wasting time and money on supposedly optimising webpages with little to no improvement in performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from pathlib import Path
import os

# Find the project root (the folder containing "data")
cwd = Path.cwd()

while not (cwd / "data").exists() and cwd != cwd.parent:
    cwd = cwd.parent

os.chdir(cwd)

df = pd.read_csv("data/raw/content_refresh_anonymized.csv", nrows=100)

# Filter to pages with at least 100 impressions
analysis = df[
    (df["impressions_90d"] >= 100)
][["word_count", "ctr"]].dropna()

# Calculate correlation
corr = analysis["word_count"].corr(analysis["ctr"])

print(f"Correlation between word_count and CTR (impressions >= 100): {corr:.5f}")
# Out:
# Correlation between word_count and CTR (impressions >= 100): -0.09850

# %% [markdown]
# This data is showing a negative correlation between word count and CTR. A machine learning model can be used to determine the optimum range or words in a page to get the macimum number of clicks.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What my works can conclude is the kind of content on a webpage that lead to more number of clicks. Content such as word count, images, font size and colour, etc. What is can't conclude is things such as how likely a website is to end up on the first page of a google search which also affects its engagement

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
